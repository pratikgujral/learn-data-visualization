# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikgujral/learn-data-visualization/blob/master/Learn_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learn Data Visualization With `Matplotlib`, `Seaborn` and `Bokeh`

# %% [markdown]
# ### Importing the libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
print("Seaborn version : ", sns.__version__)
print("Pandas version : ", pd.__version__)
print("Numpy version : ", np.__version__)
# Out:
# Seaborn version :  0.9.0
# Pandas version :  0.24.2
# Numpy version :  1.16.5

# %% [markdown]
# ### Reading datasets

# %%
# Links to datasets used in this tutorial
dataseturl_auto = r"https://assets.datacamp.com/production/repositories/558/datasets/1a03987ad77b38d61fc4c692bf64454ddf345fbe/auto-mpg.csv"

dataseturl_percent_bachelors_degrees_women_usa = r"https://assets.datacamp.com/production/repositories/558/datasets/5f4f1a9bab95fba4d7fea1ad3c30dcab8f5b9c96/percent-bachelors-degrees-women-usa.csv"
"""The data set here comes from records of undergraduate degrees awarded to women in a variety of fields from 1970 to 2011."""

dataseturl_stocks = r"https://assets.datacamp.com/production/repositories/558/datasets/8dd58ff003e399765cdf348305783b842ff1d7eb/stocks.csv"

# %%
# Reading the datasets directly from URLs
auto = pd.read_csv(dataseturl_auto)

degrees = pd.read_csv(dataseturl_percent_bachelors_degrees_women_usa)

stocks = pd.read_csv(dataseturl_stocks, index_col="Date", parse_dates=["Date"])

# %% [markdown]
# ### Viewing the `head` of all loaded DataFrames

# %%
auto.head()
# Out:
#     mpg  cyl  displ   hp  ...              name  color       size marker
# 0  18.0    6  250.0   88  ...      ford mustang    red  27.370336      o
# 1   9.0    8  304.0  193  ...          hi 1200d  green  62.199511      o
# 2  36.1    4   91.0   60  ...  honda civic cvcc   blue   9.000000      x
# 3  18.5    6  250.0   98  ...      ford granada    red  34.515625      o
# 4  34.3    4   97.0   78  ...         audi 4000   blue  13.298178      s
#
# [5 rows x 12 columns]

# %%
degrees.head()
# Out:
#    Year  Agriculture  ...  Public Administration  Social Sciences and History
# 0  1970     4.229798  ...                   68.4                         36.8
# 1  1971     5.452797  ...                   65.5                         36.2
# 2  1972     7.420710  ...                   62.6                         36.1
# 3  1973     9.653602  ...                   64.3                         36.4
# 4  1974    14.074623  ...                   66.1                         37.3
#
# [5 rows x 18 columns]

# %%
stocks.head()
# Out:
#                   AAPL       IBM      CSCO      MSFT
# Date
# 2000-01-03  111.937502  116.0000  108.0625  116.5625
# 2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2000-01-05  103.999997  116.0000  101.6875  113.8125
# 2000-01-06   94.999998  114.0000  100.0000  110.0000
# 2000-01-07   99.500001  113.5000  105.8750  111.4375

# %% [markdown]
# ### Multiple plots on a single axis

# %% [markdown]
#  - Plotting in blue the % of degrees awarded to women in the Physical Sciences
#  - Plotting in red the % of degrees awarded to women in Compuer Science

# %%
plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue')

plt.plot(degrees['Year'], degrees['Computer Science'], color='red')

plt.show()

# %% [markdown]
# ### Plot different line plots on distinct axes using `axes()`
#
# In calling `plt.axes([xlo, ylo, width, height])`, a set of axes is created and made active with lower corner at coordinates (xlo, ylo) of the specified width and height.
#
# These coordinates can be passed to plt.axes() in the form of a list or a tuple.
#
# The coordinates and lengths are values between 0 and 1 representing lengths relative to the dimensions of the figure.

# %%
plt.axes([0.05, 0.05, 0.425, 0.9])

plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue')

plt.axes([0.525, 0.05, 0.425, 0.9])

plt.plot(degrees['Year'], degrees['Computer Science'], color='red')

plt.show()

# %% [markdown]
# ### Plot different line plots on distinct axes using `subplot(..)`
#
# `plt.subplot(m, n, k)` makes a subplot grid of dimensions m by n and to make the kth subplot active (subplots are numbered starting from 1 row-wise from the top left corner of the subplot grid)

# %%
plt.subplot(2,2,1)

plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue')
plt.title('Physical Sciences')

plt.subplot(2,2,2)
plt.plot(degrees['Year'], degrees['Computer Science'], color='red')
plt.title('Computer Science')

plt.subplot(2,2,3)
plt.plot(degrees['Year'], degrees['Health Professions'], color='green')
plt.title('Health Professions')

plt.subplot(2,2,4)
plt.plot(degrees['Year'], degrees['Education'], color='yellow')
plt.title('Education')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Customizing axes using `xlim(..)`, `ylim(..)`, `xlabel(..)`, `ylabel(..)`, `title(..)`

# %%
plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue')

plt.plot(degrees['Year'], degrees['Computer Science'], color='red')

# Adding axis labels
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

# Set axis range
plt.xlim([1990, 2010])
plt.ylim([0, 50])

# Adding a title
plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')

plt.show()

# Saving the figure
plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# #### Specifying axes limits using `axis(..)`

# %%
plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue')

plt.plot(degrees['Year'], degrees['Computer Science'], color='red')

# Adding axis labels
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

# Set axis range
#plt.xlim([1990, 2010])
#plt.ylim([0, 50])
plt.axis((1990, 2010, 0, 50))

plt.show()

# Saving the figure
plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# ### Legends, Annotations and Styles

# %% [markdown]
# **`label = ..`** for specifying labels for individual plots (used for legend)
#
# **`plt.legend(..)`** for specifying location of legend

# %%
plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue', label = 'Physical Sciences')

plt.plot(degrees['Year'], degrees['Computer Science'], color='red', label = 'Computer Science')

plt.legend(loc='lower center')

plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollmen of women')
plt.show()

# %% [markdown]
# #### Annotations

# %%
plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue', label = 'Physical Sciences')
plt.plot(degrees['Year'], degrees['Computer Science'], color='red', label = 'Computer Science')

plt.legend(loc='lower right')

# Compute the maximum enrollment of women in Computer Science: cs_max
computer_science = degrees['Computer Science']
cs_max = computer_science.max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
yr_max = degrees['Year'][computer_science.idxmax()]

# Add a black arrow annotation
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max+5, cs_max+5), arrowprops=dict(facecolor='black'))

# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %% [markdown]
# #### Styling

# %%
# Setting the style
plt.style.use('ggplot')

# Plot the enrollment % of women in the Physical Sciences
plt.plot(degrees['Year'], degrees['Physical Sciences'], color='blue')
plt.title('Physical Sciences')

plt.show()

# %%
# Printing all the availoable styles
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-white', 'fast', 'seaborn-talk', 'seaborn-poster', 'seaborn-colorblind', 'bmh', 'tableau-colorblind10', 'Solarize_Light2', 'seaborn-deep', 'fivethirtyeight', 'seaborn-whitegrid', 'seaborn-notebook', '_classic_test', 'ggplot', 'seaborn-muted', 'seaborn-ticks', 'seaborn-darkgrid', 'seaborn-bright', 'seaborn-paper', 'dark_background', 'seaborn-pastel', 'grayscale', 'seaborn-dark-palette', 'classic', 'seaborn']

# %% [markdown]
# ---
#
# ## Working with 2D data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate two 1-D arrays: u, v
u = np.linspace(-2, 2, 41)
# """The array u should contain 41 values uniformly spaced beween -2 and +2"""

v = np.linspace(-1, 1, 21)
# """The array v should contain 21 values uniformly spaced between -1 and +1."""

# Generate 2-D arrays from u and v: X, Y
X,Y = np.meshgrid(u,v)
# """The resulting arrays should have shape (41,21)"""

# %%
# Compute Z based on X and Y
Z = np.sin(3*np.sqrt(X**2 + Y**2))

# %%
# Display the resulting image with pcolor()
plt.pcolor(Z)
plt.show()

# %% [markdown]
# ### Contour and filled contour plots
#
# Although `plt.imshow()` or `plt.pcolor()` are often used to visualize a 2-D array in entirety, there are other ways of visualizing such data without displaying all the available sample values. One option is to use the array to compute contours that are visualized instead.
#
# Two types of contour plot supported by Matplotlib are `plt.contour()` and `plt.contourf()` where the former displays the contours as lines and the latter displayed filled areas between contours. Both these plotting commands accept a two dimensional array from which the appropriate contours are computed.

# %%
# Generate a default contour map of the array Z
plt.subplot(2,2,1)
plt.contour(X, Y, Z)

# Generate a contour map with 20 contours
plt.subplot(2,2,2)
plt.contour(X, Y, Z, 20)

# Generate a default filled contour map of the array Z
plt.subplot(2,2,3)
plt.contourf(X, Y, Z)

# Generate a default filled contour map with 20 contours
plt.subplot(2,2,4)
plt.contourf(X, Y, Z, 20)

# Improve the spacing between subplots
plt.tight_layout()

# Display the figure
### Using different colormapsplt.show()

# %% [markdown]
# ### Using different colormaps
#
# When displaying a 2-D array with `plt.imshow()` or `plt.pcolor()`, the values of the array are mapped to a corresponding color. The set of colors used is determined by a colormap which smoothly maps values to colors, making it easy to understand the structure of the data at a glance.
#
# Default colormap is `jet`.
#
# - Some matplotlib colormaps have unique names such as `'jet'`, `'coolwarm',` `'magma'` and `'viridis'`.
# - Others have a naming scheme based on overall color such as `'Greens'`, `'Blues'`, `'Reds'`, and `'Purples'`.
# - Another four colormaps are based on the seasons, namely `'summer'`, `'autumn'`, `'winter'` and `'spring'`.
# - You can insert the option `cmap=...` into most matplotlib functions to change the color map of the resulting plot.

# %%
plt.subplot(2,2,1)
plt.contourf(X, Y, Z, 20, cmap = 'viridis')
plt.colorbar()
plt.title('Viridis')


plt.subplot(2,2,2)
plt.contourf(X, Y, Z, 20, cmap = 'gray')
plt.colorbar()
plt.title('Gray')

plt.subplot(2,2,3)
plt.contourf(X, Y, Z, 20, cmap = 'autumn')
plt.colorbar()
plt.title('Autumn')

plt.subplot(2,2,4)
plt.contourf(X, Y, Z, 20, cmap = 'winter')
plt.colorbar()
plt.title('Winter')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualizing bi-variate distributions

# %% [markdown]
# #### `hist2d(x, y, ..)`
# Given a set of ordered pairs describing data points, you can count the number of points with similar values to construct a two-dimensional histogram. This is similar to a one-dimensional histogram, but it describes the joint variation of two random variables rather than just one.
#
#
# - Specify the number of bins with the argument `bins=(nx, ny)` where nx is the number of bins to use in the horizontal direction and ny is the number of bins to use in the vertical direction.
# - You can specify the rectangular region in which the samples are counted in constructing the 2D histogram. The optional parameter required is `range=((xmin, xmax), (ymin, ymax))` where
# - `xmin` and `xmax` are the respective lower and upper limits for the variables on the x-axis and
# - `ymin` and `ymax` are the respective lower and upper limits for the variables on the y-axis. Notice that the optional `range` argument can use nested tuples or lists.

# %%
plt.hist2d(auto['hp'], auto['mpg'], bins=(10, 20), range= ((40, 235), (8,48)))

plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hist2d() plot')
plt.show()

# %% [markdown]
# As evident, cars with higher `hp` have lower `mpg`.

# %% [markdown]
# #### Using `hexbin(..)`
# The function `plt.hist2d()` uses rectangular bins to construct a two dimensional histogram.
#
# As an alternative, the function `plt.hexbin()` uses hexagonal bins. The underlying algorithm constructs a hexagonal tesselation of a planar region and aggregates points inside hexagonal bins.
#
# - The optional `gridsize` argument (default 100) gives the number of hexagons across the x-direction used in the hexagonal tiling. If specified as a list or a tuple of length two, `gridsize` fixes the number of hexagon in the x- and y-directions respectively in the tiling.
#
# - The optional parameter `extent=(xmin, xmax, ymin, ymax)` specifies rectangular region covered by the hexagonal tiling. In that case, `xmin` and `xmax` are the respective lower and upper limits for the variables on the x-axis and ymin and ymax are the respective lower and upper limits for the variables on the y-axis.

# %%
plt.hexbin(auto['hp'], auto['mpg'], gridsize = (15, 12), extent = (40, 235, 8, 48))
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hexbin() plot')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # IMAGES

# %%
from skimage import io
img = io.imread("https://raw.githubusercontent.com/opencv/opencv/master/samples/data/messi5.jpg")
plt.imshow(img)

# %%
# Print shape of the image
print(img.shape)
# Out:
# (342, 548, 3)

# %% [markdown]
# ## Pseudocolor plot from image data
# Image data comes in many forms and it is not always appropriate to display the available channels in RGB space. In many situations, an image may be processed and analysed in some way before it is visualized in pseudocolor, also known as 'false' color.
#
# We'll compute the total intensity across the red, green and blue channels. The result is a single two dimensional array which you will display using `plt.imshow()` with the `gray` colormap.

# %%
# Load the image into an array: img
img = io.imread("https://raw.githubusercontent.com/opencv/opencv/master/samples/data/messi5.jpg")

# Print the shape of the image
print(img.shape)

# Compute the sum of the red, green and blue channels: intensity
intensity = img.sum(axis=2)

# Print the shape of the intensity
print(intensity.shape)

# Display the intensity with a colormap of 'gray'
plt.imshow(intensity, cmap='gray')

# Add a colorbar
plt.colorbar()

# Hide the axes and show the figure
plt.axis('off')
plt.show()

# %% [markdown]
# # Visualizing Regressions
# [Slides from DataCamp](https://s3.amazonaws.com/assets.datacamp.com/production/course_2493/slides/ch3_slides.pdf)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Linear Regression

# %%
sns.lmplot(x='weight', y='hp', data=auto)

plt.show()

# %% [markdown]
# ### Residual Plot using `sns.residplot(..)`

# %%
sns.residplot(x='hp', y='mpg', data=auto, color='green')
plt.show()

# %% [markdown]
# ### Higher Order Regressions

# %%
# Generate a scatter plot of 'weight' and 'mpg' using red circles
plt.scatter(auto['weight'], auto['mpg'], color='red', marker='o')

# Plot in blue a linear regression of order 1 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, color='blue', scatter = None, label='Order 1')

# Plot in green a linear regression of order 2 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, color='green', scatter=None ,label='Order 2', order=2)

# Adding legend
plt.legend(loc = 'upper right')

plt.show()

# %% [markdown]
# ### Grouping linear regressions by hue
#
# Often it is useful to compare and contrast trends between different groups. Seaborn makes it possible to apply linear regressions separately for subsets of the data by applying a groupby operation. Using the `hue` argument, you can specify a categorical variable by which to group data observations. The distinct groups of points are used to produce distinct regressions with different hues in the plot

# %%
sns.lmplot(x='weight', y='hp', hue='origin', palette='Set1', data=auto)
plt.show()

# %% [markdown]
# Notice that different colors were used to plot the data points for cars belonging to different origins.
#
# Also, from the graph, it looks like `US` automobiles tend to have higher `hp`.

# %% [markdown]
# ### Grouping linear regressions by row or column
# Rather than overlaying linear regressions of grouped data in the same plot, we may want to use a grid of subplots. The `sns.lmplot()` accepts the arguments `row` and/or `col` to arrangements of subplots for regressions.

# %%
# Plot linear regression between 'weight' and 'hp' grouped row-wise by 'origin'
sns.lmplot(x='weight', y='hp', data=auto, row='origin')

plt.show()

# %%
# Plot linear regression between 'weight' and 'hp' grouped col-wise by 'origin'
sns.lmplot(x='weight', y='hp', data=auto, col='origin')

plt.show()

# %% [markdown]
# # Visualizing univariate distributions
#  - Strip Plots
#  - Swarm Plots
#  - Violin Plots

# %% [markdown]
# ## Constructing strip plots
#
# Regressions are useful to understand relationships between two continuous variables. Often we want to explore how the distribution of a single continuous variable is affected by a second categorical variable. Seaborn provides a variety of plot types to perform these types of comparisons between univariate distributions.
#
# The strip plot is one way of visualizing this kind of data. It plots the distribution of variables for each category as individual datapoints. For vertical strip plots (the default), distributions of continuous values are laid out parallel to the y-axis and the distinct categories are spaced out along the x-axis.
#
# - For example, `sns.stripplot(x='type', y='length', data=df)` produces a sequence of vertical strip plots of `length` distributions grouped by `type` (assuming `length` is a continuous column and `type` is a categorical column of the DataFrame `df`).
#
# - Overlapping points can be difficult to distinguish in strip plots. The argument `jitter=True` helps spread out overlapping points.
# Other matplotlib arguments can be passed to `sns.stripplot()`, e.g., `marker`, `color`, `size`, etc.

# %%
plt.subplot(2,1,1)

# Make a strip plot of 'hp' grouped by 'cyl'
sns.stripplot(x='cyl', y='hp', data=auto)

plt.subplot(2,1,2)
# Make a strip plot again using jitter and a smaller point size
sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=3)

plt.show()

# %% [markdown]
# ### Constructing swarm plots
# As you have seen, a strip plot can be visually crowded even with jitter applied and smaller point sizes. An alternative is provided by the swarm plot (`sns.swarmplot()`), which is very similar but spreads out the points to avoid overlap and provides a better visual overview of the data.
#
# - The syntax for `sns.swarmplot()` is similar to that of `sns.stripplot()`, e.g., `sns.swarmplot(x='type', y='length', data=df)`.
# - The orientation for the continuous variable in the strip/swarm plot can be inferred from the choice of the columns `x` and `y` from the DataFrame `data`. The orientation can be set explicitly using `orient='h' `(horizontal) or `orient='v' `(vertical).
# - Another grouping can be added in using the `hue` keyword. For instance, using `sns.swarmplot(x='type', y='length', data=df, hue='build year')` makes a swarm plot from the DataFrame `df` with the` 'length'` column values spread out vertically, horizontally grouped by the column `'type'` and each point colored by the categorical column `'build year'`.

# %%
# Generate a swarm plot of 'hp' grouped horizontally by 'cyl'  
plt.subplot(2,1,1)
sns.swarmplot(x='cyl', y='hp', data=auto)

# Generate a swarm plot of 'hp' grouped vertically by 'cyl' with a hue of 'origin'
plt.subplot(2,1,2)
sns.swarmplot(x='hp', y='cyl', data=auto, hue='origin', orient='h')

# Display the plot
plt.show()

# %% [markdown]
# ### Constructing violin plots
# Both strip and swarm plots visualize all the datapoints. For large datasets, this can result in significant overplotting. Therefore, it is often useful to use plot types which reduce a dataset to more descriptive statistics and provide a good summary of the data. Box and whisker plots are a classic way of summarizing univariate distributions but seaborn provides a more sophisticated extension of the standard box plot, called a violin plot.

# %%
# Generate a violin plot of 'hp' grouped horizontally by 'cyl'
plt.subplot(2,1,1)
sns.violinplot(x='cyl', y='hp', data=auto)

# Generate the same violin plot again with a color of 'lightgray' and without inner annotations
plt.subplot(2,1,2)
sns.violinplot(x='cyl', y='hp', data=auto, inner=None, color='lightgray')

# Overlay a strip plot on the violin plot
sns.stripplot(x='cyl', y='hp', data=auto, size=1.5, jitter=True)

# Display the plot
plt.show()

# %% [markdown]
# As you can see, violin plots are a nice way of visualizing the relationship between a continuous variable and a categorical variable.

# %% [markdown]
# # Visualizing multivariate distributions
# -  **Bivariate** : "Two variables"
# - **Multivariate** : "Multiple variables"
#
# - Visualizing relationships in multivariate data:
#   -  Joint Plots
#   -  Pair Plots
#   -  Heat Maps

# %% [markdown]
# ### Joint Plots

# %%
# Generate a joint plot of 'hp' and 'mpg'
sns.jointplot(x='hp', y='mpg', data=auto)

# Display the plot
plt.show()

# %% [markdown]
# The seaborn function `sns.jointplot()` has a parameter `kind` to specify how to visualize the joint variation of two continuous random variables (i.e., two columns of a DataFrame)
#
# - `kind='scatter' `uses a scatter plot of the data points
# - `kind='reg'` uses a regression plot (default order 1)
# - `kind='resid'` uses a residual plot
# - `kind='kde'` uses a kernel density estimate of the joint distribution
# - `kind='hex'` uses a hexbin plot of the joint distribution

# %%
# Generate a joint plot of 'hp' and 'mpg' using a hexbin plot
sns.jointplot(x='hp', y='mpg', data=auto, kind='hex')

# Display the plot
plt.show()

# %% [markdown]
# ### Pair Plots
# Data sets often contain more than two continuous variables. The function `sns.jointplot()` is restricted to representing joint variation between only two quantities (i.e., two columns of a DataFrame). Visualizing multivariate relationships is trickier.
#
# The function `sns.pairplot()` constructs a grid of all joint plots pairwise from all pairs of (non-categorical) columns in a DataFrame. The syntax is very simple: `sns.pairplot(df)`, where `df` is a DataFrame. The non-categorical columns are identified and the corresponding joint plots are plotted in a square grid of subplots. The diagonal of the subplot grid shows the univariate histograms of the individual columns.

# %%
# Print the first 5 rows of the DataFrame
print(auto.head())

# Plot the pairwise joint distributions from the DataFrame 
sns.pairplot(auto)

# Display the plot
plt.show()
# Out:
#     mpg  cyl  displ   hp  ...              name  color       size marker
# 0  18.0    6  250.0   88  ...      ford mustang    red  27.370336      o
# 1   9.0    8  304.0  193  ...          hi 1200d  green  62.199511      o
# 2  36.1    4   91.0   60  ...  honda civic cvcc   blue   9.000000      x
# 3  18.5    6  250.0   98  ...      ford granada    red  34.515625      o
# 4  34.3    4   97.0   78  ...         audi 4000   blue  13.298178      s
#
# [5 rows x 12 columns]

# %%
# Print the first 5 rows of the DataFrame
print(auto.head())

# Plot the pairwise joint distributions grouped by 'origin' along with regression lines
sns.pairplot(auto, hue='origin', kind='reg')

# Display the plot
plt.show()
# Out:
#     mpg  cyl  displ   hp  ...              name  color       size marker
# 0  18.0    6  250.0   88  ...      ford mustang    red  27.370336      o
# 1   9.0    8  304.0  193  ...          hi 1200d  green  62.199511      o
# 2  36.1    4   91.0   60  ...  honda civic cvcc   blue   9.000000      x
# 3  18.5    6  250.0   98  ...      ford granada    red  34.515625      o
# 4  34.3    4   97.0   78  ...         audi 4000   blue  13.298178      s
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Visualizing correlations with heatmaps
# - Plotting relationships between many variables using a pair plot can quickly get visually overwhelming. It is therefore often useful to compute covariances between the variables instead. The covariance matrix can then easily be visualized as a *heatmap*. A heatmap is effectively a pseudocolor plot with labelled rows and columns (i.e., a pseudocolor plot based on a pandas DataFrame rather than a matrix). The DataFrame does not have to be square or symmetric (but, in the context of a covariance matrix, it is both).
#
# - In a covariance matrix, diagonal entries are all 1s, and the off-diagonal entries are between -1 and +1 (quantifying the degree to which variable pairs vary jointly). It is also, then, a symmetric matrix

# %%
# Assuming covariance matrix has been calculated
cov_matrix = auto.cov() # INCORRECT. Needs to be corrected

print(cov_matrix)

# Visualizing the covariance matrixc using a heatmap
sns.heatmap(cov_matrix)

plt.show()
# Out:
#                 mpg          cyl  ...          yr          size
# mpg       60.918142   -10.352928  ...   16.691477    -95.753891
# cyl      -10.352928     2.909696  ...   -2.171930     23.110219
# displ   -657.585207   169.721949  ... -142.572133   1478.112751
# hp      -233.857926    55.348244  ...  -59.036432    509.121366
# weight -5517.440704  1300.424363  ... -967.228457  12814.879225
# accel      9.115514    -2.375052  ...    2.950462    -17.896926
# yr        16.691477    -2.171930  ...   13.569915    -18.219609
# size     -95.753891    23.110219  ...  -18.219609    231.292705
#
# [8 rows x 8 columns]

# %% [markdown]
# ---
#
# # Visualizing Time-Series
#
# [Link to DataCamp MP4 video](https://videos.datacamp.com/transcoded_mp4/1761_intro_dataviz_python/v3/ch4_2.mp4)
#
# [Link to DataCamp HLS video](https://videos.datacamp.com/transcoded/1761_intro_dataviz_python/v3/hls-ch4_2.master.m3u8)
#
# [Link to DataCamp slides](https://s3.amazonaws.com/assets.datacamp.com/production/course_2493/slides/ch4_slides.pdf)

# %% [markdown]
# ### Multiple time-series on a common axes

# %%
stocks.head() # Note that gthe 'Date' column has been set as index of the DataFrame
# Out:
#                   AAPL       IBM      CSCO      MSFT
# Date
# 2000-01-03  111.937502  116.0000  108.0625  116.5625
# 2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2000-01-05  103.999997  116.0000  101.6875  113.8125
# 2000-01-06   94.999998  114.0000  100.0000  110.0000
# 2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
# Import matplotlib.pyplot
import matplotlib.pyplot as plt

plt.style.use('default')

# Plot the aapl time series in blue
plt.plot(stocks['AAPL'], color='blue', label='AAPL')

# Plot the ibm time series in green
plt.plot(stocks['IBM'], color='green', label='IBM')

# Plot the csco time series in red
plt.plot(stocks['CSCO'], color='red', label='CSCO')

# Plot the msft time series in magenta
plt.plot(stocks['MSFT'], color='magenta', label='MSFT')

# Add a legend in the top left corner of the plot
plt.legend(loc='upper left')

# Specify the orientation of the xticks
plt.xticks(rotation=60)

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Multiple time series slices

# %%
# Plot the series in the top subplot in blue
plt.subplot(2,1,1)
plt.xticks(rotation=45)
plt.title('AAPL: 2001 to 2011')
plt.plot(stocks['AAPL'], color='blue')

# Slice aapl from '2007' to '2008' inclusive
view = stocks['AAPL']['2007':'2008']

# Plot the sliced data in the bottom subplot in black
plt.subplot(2,1,2)
plt.xticks(rotation=45)
plt.title('AAPL: 2007 to 2008')
plt.plot(view, color='black')
plt.tight_layout()
plt.show()

# %%
# Slice aapl from Nov. 2007 to Apr. 2008 inclusive: view
view = stocks['AAPL']['2007-11':'2008-04']

# Plot the sliced series in the top subplot in red
plt.subplot(2,1,1)
plt.plot(view, color='red')
plt.title('AAPL: Nov. 2007 to Apr. 2008')
plt.xticks(rotation=45)

# Reassign the series by slicing the month January 2008
view = stocks['AAPL']['2008-01']

# Plot the sliced series in the bottom subplot in green
plt.subplot(2,1,2)
plt.plot(view, color='green')
plt.title('AAPL: Jan. 2008')
plt.xticks(rotation=45)

# Improve spacing and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Inset Views
#  Inset views are a useful way of comparing time series data.
#
#  This can be easily made by specifying smaller dimensions for another overlaying plot using `axes(..)`.

# %%
# Slice aapl from Nov. 2007 to Apr. 2008 inclusive: view
view = stocks['AAPL']['2007-11':'2008-04']

# Plot the entire series 
plt.plot(stocks['AAPL'])
plt.xticks(rotation=45)
plt.title('AAPL: 2001-2011')

# Specify the axes
plt.axes((0.25, 0.5, 0.35, 0.30)) # (xLo, yLo, width, height)

# Plot the sliced series in red using the current axes
plt.plot(view, color='red')
plt.xticks(rotation=45)
plt.title('2007/11-2008/04')
plt.show()

# %% [markdown]
# ## Time series with moving windows

# %%
"""
# Plot std_30 in red
plt.plot(std_30, color='red', label='30d')

# Plot std_75 in cyan
plt.plot(std_75, color='cyan', label='75d')

# Plot std_125 in green
plt.plot(std_125, color='green', label='125d')

# Plot std_250 in magenta
plt.plot(std_250, color='magenta', label='250d')

# Add a legend to the upper left
plt.legend(loc='upper left')

# Add a title
plt.title('Moving standard deviations')

# Display the plot
plt.show()


"""
# Out:
# "\n# Plot std_30 in red\nplt.plot(std_30, color='red', label='30d')\n\n# Plot std_75 in cyan\nplt.plot(std_75, color='cyan', label='75d')\n\n# Plot std_125 in green\nplt.plot(std_125, color='green', label='125d')\n\n# Plot std_250 in magenta\nplt.plot(std_250, color='magenta', label='250d')\n\n# Add a legend to the upper left\nplt.legend(loc='upper left')\n\n# Add a title\nplt.title('Moving standard deviations')\n\n# Display the plot\nplt.show()\n\n\n"

# %% [markdown]
# ### Extracting a histogram from a grayscale image

# %%
image = plt.imread("https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/Unequalized_Hawkes_Bay_NZ.jpg/800px-Unequalized_Hawkes_Bay_NZ.jpg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-9ec5b05ffc02> in <module>()
# ----> 1 image = plt.imread("https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/Unequalized_Hawkes_Bay_NZ.jpg/800px-Unequalized_Hawkes_Bay_NZ.jpg")
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2150 @docstring.copy_dedent(matplotlib.image.imread)
#    2151 def imread(fname, format=None):
# -> 2152     return matplotlib.image.imread(fname, format)
#    2153
#    2154
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1362         if len(parsed.scheme) > 1:
#    1363             fd = BytesIO(urllib.request.urlopen(fname).read())
# -> 1364             return handler(fd)
#    1365         else:
#    1366             with open(fname, 'rb') as fd:
#
# ValueError: invalid PNG header

# %%
MISSINH
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-d1d76c600fe8> in <module>()
# ----> 1 MISSINH
#
# NameError: name 'MISSINH' is not defined

# %% [markdown]
# # Interactive Data Visualization with Bokeh

# %% [markdown]
# ### Datasets

# %%
import pandas as pd
from bokeh.io import output_file, show, output_notebook
from bokeh.plotting import figure

# %%
dataseturl_auto = "https://assets.datacamp.com/production/repositories/401/datasets/2a776ae9ef4afc3f3f3d396560288229e160b830/auto-mpg.csv"

dataseturl_AAPL_stock = "https://assets.datacamp.com/production/repositories/401/datasets/313eb985cce85923756a128e49d7260a24ce6469/aapl.csv"

dataseturl_gapminder = "https://assets.datacamp.com/production/repositories/401/datasets/09378cc53faec573bcb802dce03b01318108a880/gapminder_tidy.csv"

dataseturl_blood_glucose_level = "https://assets.datacamp.com/production/repositories/401/datasets/edcedae3825e0483a15987248f63f05a674244a6/glucose.csv"

dataseturl_female_literacy_and_birth_rate = "https://assets.datacamp.com/production/repositories/401/datasets/5aae6591ddd4819dec17e562f206b7840a272151/literacy_birth_rate.csv"
#  This dataset highlights that countries with low female literacy have high birthrates

dataseturl_olympic_medals_100m = "https://assets.datacamp.com/production/repositories/401/datasets/68b7a450b34d1a331d4ebfba22069ce87bb5625d/sprint.csv"

# %%
# Reading datasets
auto = pd.read_csv(dataseturl_auto)

aapl = pd.read_csv(dataseturl_AAPL_stock, parse_dates=['date'])

gapminder = pd.read_csv(dataseturl_gapminder)

blood_glucose_level = pd.read_csv(dataseturl_blood_glucose_level)

literacy = pd.read_csv(dataseturl_female_literacy_and_birth_rate)

olympic = pd.read_csv(dataseturl_olympic_medals_100m)

# %% [markdown]
# ## Chapter - 1
#
# [Link to slides](https://s3.amazonaws.com/assets.datacamp.com/production/course_2244/slides/ch1_slides.pdf)
#
# ---
#
# [Link to MP4 video-1](https://videos.datacamp.com/transcoded_mp4/1392_Bokeh_I/v5/ch1_2.mp4)
#
# [Link to HLS video-1](https//videos.datacamp.com/transcoded/1392_Bokeh_I/v5/hls-ch1_2.master.m3u8)
#
# ---
# [Link to HLS video-2](https:http:////videos.datacamp.com/transcoded/1392_Bokeh_I/v4/hls-ch1_3.master.m3u8)
#
# [Link to MP4 video-2](https://videos.datacamp.com/transcoded_mp4/1392_Bokeh_I/v4/ch1_3.mp4)
#
# ---
#
# [Link to HLS video-3](https://videos.datacamp.com/transcoded/1392_Bokeh_I/v3/hls-ch1_4.master.m3u8)
#
# [Link to MP4 video-3](https://videos.datacamp.com/transcoded_mp4/1392_Bokeh_I/v3/ch1_4.mp4)
#
# ---
# [Link to HLS video-4](https://videos.datacamp.com/transcoded/1392_Bokeh_I/v4/hls-ch1_5.master.m3u8)
#
# [Link to MP4 video-4](https://videos.datacamp.com/transcoded_mp4/1392_Bokeh_I/v4/ch1_5.mp4)

# %%
from bokeh.io import output_notebook, output_file, show
from bokeh.plotting import figure

plot = figure(plot_width=400, tools='pan, box_zoom')

plot.circle([1,2,3,4,5], [8,6,5,2,3])

output_notebook()

#output_file('circle.html')

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1127">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aeaa2998-fafa-4683-bb6f-96e8dafca397" data-root-id="1096"></div>

# %% [markdown]
# #### Creating another figure
#
# **Note:**  `x` and `y` can be a list, tuple, or may just be a single number in which case the same number will be used for all other numbers provided for the other axis.

# %%
plot = figure()

plot.circle(x=10, y=[2,5,8,12], size=[10,20,30,40])

output_notebook()

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1239">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3212a1db-5bfe-4e6a-a165-bc3a64baaf18" data-root-id="1200"></div>

# %% [markdown]
# ### Markers
# In our call to `plot.circle()` circle is a **marker**- the shape that is used to plot the data points. Options include:
# - `asterisk()`
# - `circle()`
# - `circle_cross() `
# - `circle_x() `
# - `cross() `
# - `diamond()`
# - `diamond_cross()`
# - `inverted_triangle()`
# - `square()`
# - `square_cross()`
# - `square_x()`
# - `triangle()`
# - `x()`

# %% [markdown]
# ### Glyphs
# Glyphs available
#
# - `annulus()`
# - `annular_wedge()`
# - `wedge()`
# - `rect()`
# - `quad()`
# - `vbar()`
# - `hbar()`
# - `image()`
# - `image_rgba()`
# - `image_url()`
# - `patch()`
# - `patches()`
# - `line()`
# - `multi_line()`
# - `circle()`
# - `oval()`
# - `ellipse()`
# - `arc()`
# - `quadratic()`
# - `bezier()`

# %% [markdown]
# #### Lines

# %%
x = [1,2,3,4,5]
y = [8,6,5,2,3]

plot = figure()

plot.line(x, y, line_width = 3)

output_notebook()

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1360">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fa46a29e-f5c6-4437-91c8-6c5622692011" data-root-id="1321"></div>

# %% [markdown]
# #### Lines and points

# %%
plot = figure()

plot.line(x, y, line_width = 2)

plot.triangle(x, y, fill_color='white', size=10)

output_notebook()

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1495">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="04b809df-f6db-4dd9-a381-dbc071cb4ce6" data-root-id="1451"></div>

# %% [markdown]
# ---

# %% [markdown]
# ### Exploring our datasets

# %%
aapl['date'].head()
# Out:
# 0   2000-03-01
# 1   2000-03-02
# 2   2000-03-03
# 3   2000-03-06
# 4   2000-03-07
# Name: date, dtype: datetime64[ns]

# %%
plot = figure(x_axis_type="datetime", x_axis_label='Date', y_axis_label='US Dollars')

aapl = aapl.set_index('date')

subset_aapl = aapl["March 2000" : "August 2000"]

aapl = aapl.reset_index()
subset_aapl = subset_aapl.reset_index()

plot.line(subset_aapl['date'], subset_aapl['close'])

plot.circle(subset_aapl['date'], subset_aapl['close'], fill_color='white', size=4)

output_notebook()

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1653">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f40c26a0-a2af-48a6-9d54-91866803e83c" data-root-id="1609"></div>

# %% [markdown]
# ---
#
# ## Data formats

# %% [markdown]
# ### Plotting data from NumPy arrays

# %%
import numpy as np

# Create array using np.linspace: x
x = np.linspace(0, 5, 100)

# Create array using np.cos: y
y = np.cos(x)

# Add circles at x and y
plot = figure()
plot.circle(x, y)

output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1901">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1ad2f1d7-36ed-430a-8c1c-826f2198c965" data-root-id="1862"></div>

# %% [markdown]
# ### Plotting data from Pandas DataFrames

# %%
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  ...  yr  origin              name  color  size
# 0  18.0    6  250.0   88    3139  ...  71      US      ford mustang   blue  15.0
# 1   9.0    8  304.0  193    4732  ...  70      US          hi 1200d   blue  20.0
# 2  36.1    4   91.0   60    1800  ...  78    Asia  honda civic cvcc    red  10.0
# 3  18.5    6  250.0   98    3525  ...  77      US      ford granada   blue  15.0
# 4  34.3    4   97.0   78    2188  ...  80  Europe         audi 4000  green  10.0
#
# [5 rows x 11 columns]

# %%
# Create the figure: p
plot = figure(x_axis_label='HP', y_axis_label='MPG')

# Plot mpg vs hp by color
plot.circle(auto['hp'], auto['mpg'], color=auto['color'], size=10)

# Specify the name of the output file and show the result
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4135">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2343bd5c-6224-4a75-bf23-db448e1f489a" data-root-id="4096"></div>

# %% [markdown]
# ## Bokeh `ColumnDataSource`

# %%
olympic.head()
# Out:
#                Name Country   Medal  Time  Year        color
# 0        Usain Bolt     JAM    GOLD  9.63  2012    goldenrod
# 1       Yohan Blake     JAM  SILVER  9.75  2012       silver
# 2     Justin Gatlin     USA  BRONZE  9.79  2012  saddlebrown
# 3        Usain Bolt     JAM    GOLD  9.69  2008    goldenrod
# 4  Richard Thompson     TRI  SILVER  9.89  2008       silver

# %% [markdown]
# #### Creating `ColumnDataSource` from Pandas DataFrame

# %%
from bokeh.plotting import ColumnDataSource

source = ColumnDataSource(olympic)

plot = figure()

plot.circle('Year', 'Time', source = source, color='color', size=8)

output_notebook()

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4406">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c827cced-34a3-4fe8-a8c9-4a5f2eef9aaa" data-root-id="4367"></div>

# %% [markdown]
# ---
# ### Selection and non-selection glyphs

# %%
# Create a figure with the "box_select" tool: p
plot = figure(x_axis_label='Year',y_axis_label='Time', tools='box_select')

# Add circle glyphs to the figure p with the selected and non-selected properties
plot.circle(selection_color='red', nonselection_alpha=0.1, x='Year', y='Time', source=source)

# Specify the name of the output file and show the result
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4676">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="33171275-9274-46f6-9431-35951d860e5d" data-root-id="4646"></div>

# %% [markdown]
# #### Hover Tool

# %%
# import the HoverTool
from bokeh.models import HoverTool

plot = figure()
# Add a circle glyphs to figure p
plot.circle(x, y, size=10,
         fill_color='grey', alpha=0.1, line_color=None,
         hover_fill_color='firebrick', hover_alpha=0.5,
         hover_line_color='white')

# Create a HoverTool: hover
hover = HoverTool(tooltips=None, mode='vline')

# Add the hover tool to the figure p 
plot.add_tools(hover)

# Specify the name of the output file and show the result
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4967">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="350a33d6-1cdd-40bf-9e1c-806b4fea73b5" data-root-id="4925"></div>

# %% [markdown]
# ---
# ## Colormaping

# %%
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  ...  yr  origin              name  color  size
# 0  18.0    6  250.0   88    3139  ...  71      US      ford mustang   blue  15.0
# 1   9.0    8  304.0  193    4732  ...  70      US          hi 1200d   blue  20.0
# 2  36.1    4   91.0   60    1800  ...  78    Asia  honda civic cvcc    red  10.0
# 3  18.5    6  250.0   98    3525  ...  77      US      ford granada   blue  15.0
# 4  34.3    4   97.0   78    2188  ...  80  Europe         audi 4000  green  10.0
#
# [5 rows x 11 columns]

# %%
from bokeh.models import CategoricalColorMapper

# %%
source = ColumnDataSource(auto)

color_mapper = CategoricalColorMapper(factors=['Europe','Asia','US'], palette = ['red','green','blue'])

plot = figure()
plot.circle('weight', 'mpg', source=source, color=dict(field='origin', transform=color_mapper), legend='origin')

output_notebook()

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5275">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cc2f6345-2c3c-41c8-8ac8-63cb2d9d9a87" data-root-id="5227"></div>

# %% [markdown]
# ---

# %% [markdown]
# # Chapter - 2 Layouting

# %% [markdown]
# [Link to slides](https://s3.amazonaws.com/assets.datacamp.com/production/course_2244/slides/ch2_slides.pdf)
#
# ---
# [Link to HLS video-1](https://videos.datacamp.com/transcoded/1392_Bokeh_I/v3/hls-ch2_1.master.m3u8)
#
# [Link to MP4 video-1](https://videos.datacamp.com/transcoded_mp4/1392_Bokeh_I/v3/ch2_1.mp4)
#
# ---

# %%
# Using literacy dataset
literacy.head()
# Out:
#     Country  Continent female literacy fertility    population
# 0      Chine       ASI            90.5     1.769  1.324655e+09
# 1       Inde       ASI            50.8     2.682  1.139965e+09
# 2        USA       NAM              99     2.077  3.040600e+08
# 3  Indonésie       ASI            88.8     2.132  2.273451e+08
# 4     Brésil       LAT            90.2     1.827  1.919715e+08

# %% [markdown]
# ### Arranging multiple plots
# There can be multiple ways to layout the plots
#  - Rows and columns
#  - Grid arrangements
#  - Tabbed layouts

# %% [markdown]
# #### Rows and columns

# %%
literacy.head()
# Out:
#     Country  Continent female literacy fertility    population
# 0      Chine       ASI            90.5     1.769  1.324655e+09
# 1       Inde       ASI            50.8     2.682  1.139965e+09
# 2        USA       NAM              99     2.077  3.040600e+08
# 3  Indonésie       ASI            88.8     2.132  2.273451e+08
# 4     Brésil       LAT            90.2     1.827  1.919715e+08

# %%
# Import row from bokeh.layouts
from bokeh.layouts import row, column

source = ColumnDataSource(literacy)

# Create the first figure: p1
p1 = figure(x_axis_label='fertility (children per woman)', y_axis_label='female_literacy (% population)')

# Add a circle glyph to p1
p1.circle('fertility', 'female literacy', source=source)

# Create the second figure: p2
p2 = figure(x_axis_label='population', y_axis_label='female_literacy (% population)')

# Add a circle glyph to p2
p2.circle('population', 'female literacy', source=source)

# Put p1 and p2 into a horizontal row: layout
layout = row(p1, p2)

layout2 = column(p1, p2)

# Specify the name of the output_file and show the result
output_notebook()
print("Rows")
show(layout)
print("\n\nColumns")
show(layout2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8647">Loading BokehJS ...</span>
#     </div>
# Rows
#   <div class="bk-root" id="11286516-f983-4b86-a399-d0ed95fc1b3e" data-root-id="8645"></div>
# Columns
#   <div class="bk-root" id="76160ab2-7293-4300-ac21-273dfa1f9670" data-root-id="8646"></div>
